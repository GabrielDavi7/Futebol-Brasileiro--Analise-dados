# %%
import sys
from pathlib import Path
raiz_projeto = Path().resolve().parent
sys.path.append(str(raiz_projeto))
from scripts.dataLoader import carregar_dados

df_brasileirao, df_copa = carregar_dados()
from IPython.display import Markdown, display

# Formatando os números
total_b = f"{df_brasileirao.shape[0]:,}".replace(',', '.')
total_c = f"{df_copa.shape[0]:,}".replace(',', '.')

# Criando a visualização com Markdown
display(Markdown(f"* **Brasileirão Série A:** `{total_b}` partidas registradas."))
display(Markdown(f"* **Copa do Brasil:** `{total_c}` partidas registradas."))
# Out:
#  Data Base carregadas com sucesso.
# * **Brasileirão Série A:** `8.453` partidas registradas.
# * **Copa do Brasil:** `598` partidas registradas.
